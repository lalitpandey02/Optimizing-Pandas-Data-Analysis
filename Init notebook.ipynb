# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: ydata-profiling[notebook,unicode] in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: pandas==1.5.3 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas==1.5.3->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas==1.5.3->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas==1.5.3->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2.11.3)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.9.1)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.13.5)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.10.2)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (4.3.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (6.0)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: htmlmin==0.1.12 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (4.11.2)
# Requirement already satisfied: ipywidgets>=7.5.1 in /root/venv/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (8.0.4)
# Requirement already satisfied: jupyter-client>=5.3.4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (7.4.3)
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: PyWavelets in /root/venv/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: networkx>=2.4 in /root/venv/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (3.0)
# Requirement already satisfied: attrs>=19.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /root/venv/lib/python3.9/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (6.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /root/venv/lib/python3.9/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (4.0.5)
# Requirement already satisfied: ipython>=6.1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (8.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=5.3.4->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.4)
# Requirement already satisfied: pyzmq>=23.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=5.3.4->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (24.0.1)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=5.3.4->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.5.6)
# Requirement already satisfied: tornado>=6.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=5.3.4->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (6.2)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: joblib>=0.14.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas==1.5.3->-r ./requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: patsy>=0.5.2 in /root/venv/lib/python3.9/site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: psutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (5.9.3)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: stack-data in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.17.2)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (3.0.31)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: executing in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: asttokens in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (2.0.8)
# Requirement already satisfied: pure-eval in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook,unicode]->-r ./requirements.txt (line 1)) (0.2.2)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=761b02e4-c281-41aa-8889-a95fd514448c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
